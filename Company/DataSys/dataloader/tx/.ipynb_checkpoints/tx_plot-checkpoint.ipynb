# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False #用来正常显示负号

# %%
path = r'C:\Users\ASUS\Desktop\临港景鸿机房陪同.xlsx'
df_excel_basic = pd.read_excel(path)

# %%
df_excel_basic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  6 non-null      object
#  1   一网通办机房申请数   6 non-null      int64
#  2   实际机房陪同数     6 non-null      int64
#  3   普通申请陪同数     6 non-null      int64
#  4   紧急申请陪同数     6 non-null      int64
#  5   项目申请陪同数     6 non-null      int64
#  6   抢修申请陪同数     6 non-null      int64
#  7   总陪同时长（小时）   6 non-null      float64
# dtypes: float64(1), int64(6), object(1)
# memory usage: 512.0+ bytes

# %%
df_excel_basic.describe()
# Out:
#         一网通办机房申请数     实际机房陪同数     普通申请陪同数    紧急申请陪同数    项目申请陪同数    抢修申请陪同数  \
# count    6.000000    6.000000    6.000000   6.000000   6.000000   6.000000
# mean   219.000000  162.333333  160.833333  17.666667  19.833333  10.666667
# std     24.698178   39.827963   27.447526   9.437514  21.627914  12.388166
# min    187.000000  130.000000  110.000000   7.000000   0.000000   0.000000
# 25%    200.250000  137.500000  156.750000  11.500000   1.250000   1.250000
# 50%    220.500000  148.000000  166.500000  15.000000  14.500000   8.000000
# 75%    240.000000  170.500000  180.750000  24.500000  39.000000  14.750000
# max    246.000000  236.000000  183.000000  31.000000  46.000000  32.000000
#
#         总陪同时长（小时）
# count    6.000000
# mean   290.893333
# std     66.101027
# min    193.600000
# 25%    264.350000
# 50%    279.940000
# 75%    338.280000
# max    375.000000

# %%
df_excel_basic.plot()
plt.show()

# %%
list(df_excel_basic.keys().values)
one = '一网通办机房申请数'
signal = ['普通申请陪同数','紧急申请陪同数','项目申请陪同数','抢修申请陪同数']

# %%
df_excel_basic[one].values.shape[0]
# Out:
# 6

# %%
n_groups = 4
means_frank = (90, 55, 40, 65)
means_guido = (85, 62, 54, 20)

# 创建图形
fig, ax = plt.subplots()

# 定义条形图在横坐标上的分类位置
index = np.arange(n_groups)
bar_width = 0.1
opacity = 1

# 绘制第一个条形图
rectsl = plt.bar(index, # 定义第一个条形图的X轴坐标信息
                 means_frank, # 定义Y轴坐标信息
                 bar_width, # 定义图形的宽度
                 alpha = opacity, # 定义图形的透明度
                 color = 'b', edgecolor='k',
                 hatch = '.....',
                 label = '张三') # 定义图形的标签信息

# 绘制第二个条形图

rectsl2 = plt.bar(index,
                 means_guido,
                 bar_width,
                 bottom=means_frank,
                 alpha = opacity,
                 color = 'w', edgecolor='k',
                 hatch = r'\\\\',
                 label = '李四') # 定义第二个条形图的标签信息
plt.xlabel('课程')
plt.ylabel('分数')
plt.title('分数对比图')
plt.xticks(index+bar_width, ('A', 'B','C','D'))
plt.legend
plt.show()

# %%
n_groups = df_excel_basic[one].values.shape[0]
df_one = df_excel_basic[one].values
df_signal = [df_excel_basic[label].values for label in signal]

# 创建图形
fig, ax = plt.subplots()

# 定义条形图在横坐标上的分类位置
bar_width = 0.1
opacity = 1
indexone = np.arange(n_groups)-bar_width/2
indexsignal = indexone+bar_width

# 绘制第一个条形图
rectsl = plt.bar(index, # 定义第一个条形图的X轴坐标信息
                 means_frank, # 定义Y轴坐标信息
                 bar_width, # 定义图形的宽度
                 alpha = opacity, # 定义图形的透明度
                 color = 'b', edgecolor='k',
                 hatch = '.....',
                 label = '张三') # 定义图形的标签信息

# 绘制第二个条形图

rectsl2 = plt.bar(index,
                 means_guido,
                 bar_width,
                 bottom=means_frank,
                 alpha = opacity,
                 color = 'w', edgecolor='k',
                 hatch = r'\\\\',
                 label = '李四') # 定义第二个条形图的标签信息
plt.xlabel('课程')
plt.ylabel('分数')
plt.title('分数对比图')
plt.xticks(index+bar_width, ('A', 'B','C','D'))
plt.legend
plt.show()
